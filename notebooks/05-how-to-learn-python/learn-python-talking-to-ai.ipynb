# %% [markdown]
# # Exercise 1: Contact Book (Dictionaries & Functions)
#
# Build a contact book program that stores names, emails, and phone numbers.
# Your task:
#
# Create an empty dictionary called contacts
# 1. Write a function add_contact(name, email, phone) that adds a contact
# 2. Write a function find_contact(name) that returns the contact info or "Not found"
# 3. Write a function list_contacts() that prints all contacts
#
# Test it: Add 3 contacts, list them all, then search for one by name.

# %%
contacts = {}

def add_contact(name, email, phone):
    contacts[name] = [email, phone]

    return contacts

def find_contact(name):
    if name in contacts.keys():
        return contacts[name]
    else:
        return "Not found"

def list_contacts():
    for ct in contacts.keys():
        print(ct)

    return "done"

    

contacts = add_contact("lucas", "something@nothing.com", "111-222")
contacts
# Out:
# {'lucas': ['something@nothing.com', '111-222']}

# %%
contacts = add_contact("john", "nothing@something.com", "222-333")
contacts
# Out:
# {'lucas': ['something@nothing.com', '111-222'],
#  'john': ['nothing@something.com', '222-333']}

# %%
find_contact("lucas")
# Out:
# ['something@nothing.com', '111-222']

# %%
def list_contacts():
    for ct in contacts.keys():
        print(ct)

    return "done"

    

list_contacts()
# Out:
# lucas
# john
# 'done'

# %%
import sys
sys.path.append("../../scripts/")
from ai_tools import ask_ai

# %%
from IPython.display import Markdown

prompt = "I want to practice Python basics give me one exercise output should be just the exercise as markdown"

output = ask_ai(prompt)

Markdown(output)
# Out:
# ```markdown
# ## Python Basics Exercise
#
# ### Exercise: Fibonacci Sequence
#
# Write a Python function called `fibonacci(n)` that takes a positive integer `n` as an argument and returns the first `n` numbers of the Fibonacci sequence as a list.
#
# The Fibonacci sequence is defined as follows:
# - The first two numbers in the sequence are 0 and 1.
# - Each subsequent number is the sum of the two preceding ones.
#
# #### Example Output:
#
# ```
# fibonacci(5)
# ```
# **Expected Output:**
# ```
# [0, 1, 1, 2, 3]
# ```
#
# #### Requirements:
# - Use a loop or recursion to generate the sequence.
# - Ensure the function handles cases where `n` is 0 or negative by returning an empty list.
#
# ### Bonus Challenge:
# Modify the function to also return the sum of the provided Fibonacci sequence.
# ```
